# %%
import pandas as pd

# %%
clicks_train = pd.read_csv('clicks_train.csv')

# %%
clicks_test = pd.read_csv('clicks_test.csv')

# %%
clicks_test.head(5)
# Out:
#    display_id   ad_id
# 0    16874594   66758
# 1    16874594  150083
# 2    16874594  162754
# 3    16874594  170392
# 4    16874594  172888

# %%
events.head()
# Out:
#    display_id            uuid  document_id  timestamp platform geo_location  \
# 0           1  cb8c55702adb93       379743         61        3    US>SC>519
# 1           2  79a85fa78311b9      1794259         81        2    US>CA>807
# 2           3  822932ce3d8757      1179111        182        2    US>MI>505
# 3           4  85281d0a49f7ac      1777797        234        2    US>WV>564
# 4           5  8d0daef4bf5b56       252458        338        2        SG>00
#
#     test
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
clicks_train.display_id.max()
# Out:
# 16874593

# %%
events = pd.read_csv('events.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
events['test'] = events.display_id >16874593

# %%
page_views = pd.read_csv('page_views.csv',chunksize=1000)

# %%
tmp = page_views.get_chunk()

# %%
promoted_content = pd.read_csv('promoted_content.csv')

# %%
clicks_train.groupby('ad_id')['clicked'].mean()
# Out:
# ad_id
# 1         0.000000
# 2         0.045455
# 3         0.068323
# 4         0.125000
# 5         0.000000
# 6         0.000000
# 7         0.289196
# 8         0.142857
# 9         0.000000
# 10        0.111111
# 11        0.000000
# 12        0.166667
# 13        0.125000
# 14        0.100000
# 15        0.000000
# 16        0.333333
# 17        0.100000
# 18        0.000000
# 20        0.000000
# 21        0.000000
# 22        0.000000
# 23        0.181818
# 24        0.000000
# 25        0.000000
# 26        0.045455
# 27        0.000000
# 28        0.000000
# 29        0.000000
# 30        0.000000
# 31        0.166667
#             ...
# 547501    0.000000
# 547504    0.000000
# 547505    0.000000
# 547509    0.000000
# 547513    0.000000
# 547522    0.125000
# 547548    0.750000
# 547552    0.000000
# 547554    0.000000
# 547561    0.000000
# 547562    0.000000
# 547572    0.000000
# 547573    0.000000
# 547576    0.000000
# 547581    0.000000
# 547582    0.222222
# ...

# %%
events.head(5)
# Out:
#    display_id            uuid  document_id  timestamp platform geo_location  \
# 0           1  cb8c55702adb93       379743         61        3    US>SC>519
# 1           2  79a85fa78311b9      1794259         81        2    US>CA>807
# 2           3  822932ce3d8757      1179111        182        2    US>MI>505
# 3           4  85281d0a49f7ac      1777797        234        2    US>WV>564
# 4           5  8d0daef4bf5b56       252458        338        2        SG>00
#
#     test
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
events.uuid.value_counts().median()
# Out:
# 1.0

# %%
events.dtypes
# Out:
# display_id       int64
# uuid            object
# document_id      int64
# timestamp        int64
# platform        object
# geo_location    object
# test              bool
# dtype: object

# %%
events.document_id.value_counts()
# Out:
# 1179111    319203
# 394689     208574
# 1827718    195070
# 38922       86380
# 1788295     68509
# 2102553     67229
# 7054        66240
# 1060089     53369
# 1690147     49215
# 38915       47918
# 1493650     44134
# 2150689     42671
# 1448387     40213
# 1316528     37172
# 1535449     35074
# 467462      34570
# 1717049     33816
# 1108855     33583
# 1666933     32148
# 1271578     31970
# 1077294     31901
# 1980824     29804
# 1026091     28754
# 2165306     28103
# 1280592     27494
# 1198481     26596
# 1178289     26248
# 427953      26025
# 357569      25697
# 1027695     23972
#             ...
# 1978294         1
# 234693          1
# 185581          1
# 1634158         1
# 955749          1
# 1686909         1
# 175137          1
# 2150573         1
# 1797913         1
# 2183325         1
# 1381908         1
# 1437385         1
# 1316404         1
# 1568393         1
# 1545796         1
# 1513044         1
# 1529436         1
# 1136284         1
# 1076857         1
# ...

# %%
clicks_train.head()
# Out:
#    display_id   ad_id  clicked
# 0           1   42337        0
# 1           1  139684        0
# 2           1  144739        1
# 3           1  156824        0
# 4           1  279295        0

# %%
len(clicks_train.ad_id.value_counts())
# Out:
# 478950

# %% [markdown]
# Let's get historical concordance of contexts and ads clicked
# using clicks_train

# %%
clicks_train.groupby('display_id')['ad_id','clicked'].pipe(lambda x: )

# %%
clicks_train_smp = clicks_train.head(500)

# %%
clicks_concord = clicks_train_smp.pivot(index = 'display_id', columns='ad_id',values='clicked')

# %%
clicks_concord
# Out:
# ad_id       3685    5116    5292    5558    5760    7432    8386    8748    \
# display_id
# 1              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10             NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11             NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
clicks_concord.columns = ['ad_' + str(c) for c in clicks_concord.columns]

# %%
import math

# %%
clicks_concord.query('ad_5116 == ad_5116').filter(axis = 0, items = [0,1])
# Out:
# Empty DataFrame
# ...

# %%
clicks_concord.columns
# Out:
# Int64Index([  3685,   5116,   5292,   5558,   5760,   7432,   8386,   8748,
#              10731,  13030,
#             ...
#             330189, 330981, 331260, 331466, 332908, 333491, 333874, 334742,
#             335983, 340041],
#            dtype='int64', name=u'ad_id', length=447)
